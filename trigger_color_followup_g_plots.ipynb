# %%
from wand.image import Image as WImage
from IPython.display import Image
import IPython
import wand
from wand.display import display
from IPython.display import HTML
beta = ['0.1','0.2','0.3']
M_solar = ['0.001','0.01','0.1']
for b in beta:
    for M in M_solar:
        foldername = 'plots_b'+b+'_m'+M
        filename = foldername+'/trigger_color_followup_g_shallow.png'
        img = WImage(filename=filename)
        print 'b: ',b,' M: ',M
        IPython.display.display(Image(filename=filename))
# Out:
# b:  0.1  M:  0.001
# b:  0.1  M:  0.01
# b:  0.1  M:  0.1
# b:  0.2  M:  0.001
# b:  0.2  M:  0.01
# b:  0.2  M:  0.1
# b:  0.3  M:  0.001
# b:  0.3  M:  0.01
# b:  0.3  M:  0.1

# %%
for b in beta:
    for M in M_solar:
        foldername = 'plots_b'+b+'_m'+M
        filename = foldername+'/trigger_color_followup_g_deep.png'
        img = WImage(filename=filename)
        print 'b: ',b,' M: ',M
        IPython.display.display(Image(filename=filename))
# Out:
# b:  0.1  M:  0.001
# b:  0.1  M:  0.01
# b:  0.1  M:  0.1
# b:  0.2  M:  0.001
# b:  0.2  M:  0.01
# b:  0.2  M:  0.1
# b:  0.3  M:  0.001
# b:  0.3  M:  0.01
# b:  0.3  M:  0.1
